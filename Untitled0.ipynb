# %%
# !pip install -q kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json #fungsi untuk memberikan izin akses file

# %%
# !kaggle datasets download -d akshaydattatraykhare/diabetes-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/akshaydattatraykhare/diabetes-dataset
# License(s): CC0-1.0
# Downloading diabetes-dataset.zip to /content
#   0% 0.00/8.91k [00:00<?, ?B/s]
# 100% 8.91k/8.91k [00:00<00:00, 9.95MB/s]

# %%
import zipfile

with zipfile.ZipFile('diabetes-dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterswarnings('ignore')

from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-0ea2320caaa1> in <cell line: 6>()
#       4 import matplotlib.pyplot as plt
#       5 import warnings
# ----> 6 warnings.filterswarnings('ignore')
#       7
#       8 from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
#
# AttributeError: module 'warnings' has no attribute 'filterswarnings'

# %% [markdown]
# 3. Load & Display Dataset

# %%
df = pd.read_csv('/content/diabetes.csv')
display(df.head(2)) # display fisrt record of data
display(df.tail(2)) # display last 4 rocord of data
display(df.sample(4)) # display ramdomly any number of record of data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-bd77f45b9c22> in <cell line: 1>()
# ----> 1 df = pd.read_csv('/content/diabetes.csv')
#       2 display(df.head(2)) # display fisrt record of data
#       3 display(df.tail(2)) # display last 4 rocord of data
#       4 display(df.sample(4)) # display ramdomly any number of record of data
#
# NameError: name 'pd' is not defined
